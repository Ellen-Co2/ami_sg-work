# %%
from pandas import DataFrame, Series
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import sqlite3
from sqlalchemy import create_engine

# %%
ad = str(raw_input("please enter the full directory contains database to query: "))
# unix/mac: 'sqlite:////absolute/path/to/xxx.db'
#/Users/AAA218/Desktop/amifull_sg/
# win: 'sqlite:///C:\\path\\to\\xxx.db'
db_name = str(raw_input("please enter the full database name to query: "))
s = 'sqlite:///' + ad + db_name
print s
disk_engine = create_engine(s)
# Out:
# please enter the directory contains database for query: /Users/AAA218/Desktop/amifull_sg/
# please enter the database name for query: new.sqlite
# sqlite:////Users/AAA218/Desktop/amifull_sg/new.sqlite

# %% [markdown]
# ### Display counts across time

# %%
number = pd.read_sql_query('SELECT DISTINCT mac,COUNT(*) as `device_numbers`,sgtime,bldid FROM wifi GROUP BY sgtime,bldid',disk_engine)

# %%
print number.head()
print number.shape
# Out:
#                  mac  device_numbers               sgtime    bldid
# 0  e8:50:8b:94:67:3b               1  2016-04-16 00:00:01  SDE1-02
# 1  f4:f2:6d:16:c9:0f               8  2016-04-16 00:00:01  SDE1-03
# 2  f4:f2:6d:17:7f:ad              10  2016-04-16 00:00:01  SDE1-04
# 3  f4:f2:6d:17:7e:95               2  2016-04-16 00:00:01  SDE1-05
# 4  00:21:91:84:c1:b6               1  2016-04-16 00:00:01  SDE2-01
# (54348, 4)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
number.sgtime = pd.to_datetime(number['sgtime'])
plt.figure()
plt.plot(number[number['bldid']=='SDE1-02'].sgtime,number[number['bldid']=='SDE1-02'].device_numbers,'k')

# %% [markdown]
# ## interactive show counts distribution
# ### plotly imports
# * need to connect to internet

# %%
from plotly.widgets import GraphWidget
from IPython.display import display
import plotly.plotly as py # interactive graphing
py.sign_in('coowesome', 'ar6x3dtl5c')
from plotly.graph_objs import Bar, Scatter, Marker, Layout

buildings = list(number.bldid.unique())
traces = []
for bld in buildings:
    plo_df = number[number['bldid']==bld]
    traces.append(Bar(x=plo_df['sgtime'],y = plo_df['device_numbers'],name = bld))
py.iplot({'data':traces,'layout': Layout(barmode = 'stack',xaxis={'tickangle': 40}, margin={'b': 150})}, filename='device detected by buildings')

# %% [markdown]
# ### Query for device movement in period

# %%
from datetime import datetime, timedelta
from bokeh.plotting import figure, output_notebook, show
from bokeh.io import push_notebook

# %% [markdown]
# ### initial values generate

# %%
start = "2016-04-16 08:10:01"
lag = 80
sec = lag*60
end = datetime.strptime(start, "%Y-%m-%d %H:%M:%S")+ timedelta(seconds = sec)
print end
# Out:
# 2016-04-16 09:30:01

# %%
mac_list = pd.read_sql_query('SELECT mac,status,sgtime,bldid,firstlocatedtime FROM wifi WHERE sgtime >= "{}" AND sgtime <= "{}"'.format(start,end),disk_engine)

# %%
l = mac_list[mac_list.bldid=='SDE2-03']["mac"].unique()

# %%
counts = dict()
bld ="SDE2-03"
for id in l:
    df_mac = mac_list[mac_list.mac==id]
     # only get those appears at bld in the first time
    print "first rec:" ,df_mac[df_mac["sgtime"] == min(df_mac.sgtime)]["bldid"].iloc[0]
    if df_mac[df_mac["sgtime"] == min(df_mac.sgtime)]["bldid"].iloc[0] == bld:
        if df_mac.shape[0] == 1:
            counts["UNKNOWN"] = counts.get("UNKNOWN",0) + 1
            continue
        #store the building appeared in the time period
        else:
            b_list = df_mac.bldid.unique()
            #print b_list
            if (len(b_list) == 1):
                counts["STAY"] = counts.get("STAY",0) + 1
                continue
            else:
                for b in b_list:
                    counts[b] = counts.get(b,0) + 1
                    continue
# Out:
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE2-02
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE1-03
# first rec: SDE3-03
# first rec: SDE2-03
# first rec: SDE1-03
# first rec: SDE2-03
# first rec: SDE2-03
# first rec: SDE3-01
# first rec: SDE3-02
# first rec: SDE1-03
# first rec: SDE2-03
# first rec: SDE3-01
# first rec: SDE2-03
# first rec: SDE2-02
# first rec: SDE2-03
# first rec: SDE2-03

# %%
counts
# Out:
# {u'SDE1-03': 1,
#  u'SDE2-01': 1,
#  u'SDE2-02': 1,
#  u'SDE2-03': 3,
#  'STAY': 8,
#  'UNKNOWN': 4}

# %%
import ipywidgets as wigts
from ipywidgets import interact
w = wigts.Select(description='buildings:',options=['SDE1-02',"SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04"])
time_intev = wigts.FloatSlider(value=80,min=20,max=120.0,step=10,description='Interval(in mins):')

# %%
x = ["UNKNOWN",'SDE1-02',"SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04","STAY"]
#y = [5, 0,0,0,0,0, 0,0,1, 1, 8,0,0]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b05d6a57-e5f4-4518-970b-7ddb2b28a22d">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title = "Device Movement",x_range = x,width = 800)
r = p.circle(counts.keys(), counts.values(), size=10, fill_color="orange")
#show(p)

# %%
def crowd_flow(start = "2016-04-16 08:10:01", bld = 'SDE2-03',lag = 80 ):
    sec = lag*60
    end = datetime.strptime(start, "%Y-%m-%d %H:%M:%S")+ timedelta(seconds = sec)
    mac_list = pd.read_sql_query('SELECT mac,status,sgtime,bldid,firstlocatedtime FROM wifi WHERE sgtime >= "{}" AND sgtime <= "{}"'.format(start,end),disk_engine)
    l = mac_list[mac_list.bldid==bld]["mac"].unique()
    counts = dict()
    for id in l:
        df_mac = mac_list[mac_list.mac==id]
        # only get those appears at bld in the first time
        #print "first rec:" ,df_mac[df_mac["sgtime"] == min(df_mac.sgtime)]["bldid"].iloc[0]
        if df_mac[df_mac["sgtime"] == min(df_mac.sgtime)]["bldid"].iloc[0] == bld:
            if df_mac.shape[0] == 1:
                counts["UNKNOWN"] = counts.get("UNKNOWN",0) + 1
                continue
            #store the building appeared in the time period
            else:
                b_list = df_mac.bldid.unique()
                #print b_list
                if (len(b_list) == 1):
                    counts["STAY"] = counts.get("STAY",0) + 1
                    continue
                else:
                    for b in b_list:
                        counts[b] = counts.get(b,0) + 1
                        continue
    r.data_source.data['y'] = counts.values()
    r.data_source.data['x'] = counts.keys()
    push_notebook()

# %%
import ipywidgets as wigts
from ipywidgets import interact
interact(crowd_flow,bld = ['SDE1-02',"SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04"],lag=(10,240,10))

from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
#output_file("categorical.html")

output_notebook()

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7447bbef-9d15-454e-aa3b-8b2644c41142"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7447bbef-9d15-454e-aa3b-8b2644c41142");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7447bbef-9d15-454e-aa3b-8b2644c41142' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"20bee1cb-ee98-4006-b44e-9fea271f7739":{"roots":{"references":[{"attributes":{"formatter":{"id":"b075e5fc-5a53-4643-8469-99dfb1e26400","type":"CategoricalTickFormatter"},"plot":{"id":"61e05c06-dcad-4acc-9018-80cce9050b35","subtype":"Figure","type":"Plot"},"ticker":{"id":"14e6e4dc-e702-4e40-ba06-9221e8dfe94f","type":"CategoricalTicker"}},"id":"124a0679-c8f3-4706-b6fc-d30e095df065","type":"CategoricalAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"89176633-3d73-4e74-9c58-18539e56808b","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"61e05c06-dcad-4acc-9018-80cce9050b35","subtype":"Figure","type":"Plot"},"ticker":{"id":"929aec85-75b1-4234-9bde-9e5ff25c9014","type":"BasicTicker"}},"id":"a1cdc964-7281-441f-83e0-2eebbcca8268","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6ad1982d-66e8-4fe9-840f-8bf00e5c742f","type":"PanTool"},{"id":"492be40b-7fff-4ea5-992f-a9a49f00bab2","type":"WheelZoomTool"},{"id":"6070cf18-d6b1-4a7a-89cb-207b7adf5722","type":"BoxZoomTool"},{"id":"aec32e89-4e4a-4885-8bdb-cc098c3c1125","type":"SaveTool"},{"id":"88ba255d-0a3e-4f8f-832c-a22ef9638d71","type":"ResetTool"},{"id":"0bc8adc1-5a04-4d3f-892a-b63bf71d4b7c","type":"HelpTool"}]},"id":"2e942733-cfad-42c5-ba7c-128fb6d39875","type":"Toolbar"},{"attributes":{"plot":{"id":"61e05c06-dcad-4acc-9018-80cce9050b35","subtype":"Figure","type":"Plot"}},"id":"88ba255d-0a3e-4f8f-832c-a22ef9638d71","type":"ResetTool"},{"attributes":{},"id":"18725a20-db1b-41ae-bf3c-80d331cab1e4","type":"ToolEvents"},{"attributes":{"plot":{"id":"61e05c06-dcad-4acc-9018-80cce9050b35","subtype":"Figure","type":"Plot"}},"id":"0bc8adc1-5a04-4d3f-892a-b63bf71d4b7c","type":"HelpTool"},{"attributes":{},"id":"14e6e4dc-e702-4e40-ba06-9221e8dfe94f","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"61e05c06-dcad-4acc-9018-80cce9050b35","subtype":"Figure","type":"Plot"}},"id":"492be40b-7fff-4ea5-992f-a9a49f00bab2","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"33fac74e-9712-43a9-9e1f-a92d22df57cf","type":"ColumnDataSource"},"glyph":{"id":"94c1fec4-0820-4285-9f15-9665e39b24c5","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"54f109e3-adbc-47f7-aa0c-6b84afef7c87","type":"Circle"},"selection_glyph":null},"id":"d454bc7d-fd73-4918-82e5-3d74976a26cd","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["UNKNOWN","SDE2-02","SDE2-03","SDE2-01","STAY","SDE1-03"],"y":[4,1,3,1,8,1]}},"id":"33fac74e-9712-43a9-9e1f-a92d22df57cf","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["UNKNOWN","SDE1-02","SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04","STAY"]},"id":"61386738-43f4-40c6-b97b-2565f90cff9a","type":"FactorRange"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"54f109e3-adbc-47f7-aa0c-6b84afef7c87","type":"Circle"},{"attributes":{"below":[{"id":"124a0679-c8f3-4706-b6fc-d30e095df065","type":"CategoricalAxis"}],"left":[{"id":"9e83b6cb-f0df-4508-a582-4abbdc31ac2a","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"124a0679-c8f3-4706-b6fc-d30e095df065","type":"CategoricalAxis"},{"id":"31ae3393-dfb8-4c37-828f-76fd2819aa86","type":"Grid"},{"id":"9e83b6cb-f0df-4508-a582-4abbdc31ac2a","type":"LinearAxis"},{"id":"a1cdc964-7281-441f-83e0-2eebbcca8268","type":"Grid"},{"id":"89176633-3d73-4e74-9c58-18539e56808b","type":"BoxAnnotation"},{"id":"d454bc7d-fd73-4918-82e5-3d74976a26cd","type":"GlyphRenderer"}],"title":{"id":"f89be8 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[63]</strong>&gt;</code></p>

# %% [markdown]
# ### Query for spatial pattern changing

# %% [markdown]
# * test __bokeh widgets__

# %%
#select = Select(title="Building Option:", value="SDE1-02", options=['SDE1-02',"SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04"])

from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Select

#output_file("select.html")

select = Select(title="Building Option:", value="SDE1-02", options=['SDE1-02',"SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04"])
show(widgetbox(select))
def building_hd(attr, old ,new):
    print "old",old
    print "new",new
print select.on_change("value", building_hd)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c3500bd0-6b53-4b9a-bc72-ba46619e77d1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c3500bd0-6b53-4b9a-bc72-ba46619e77d1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c3500bd0-6b53-4b9a-bc72-ba46619e77d1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6fad71c7-3902-4085-a63c-01a627c7db34":{"roots":{"references":[{"attributes":{"children":[{"id":"21ba4064-36f4-423a-8ac5-02c6fd1e7917","type":"Select"}]},"id":"72eccb08-67db-43d2-86e9-2a426e88965e","type":"WidgetBox"},{"attributes":{"callback":null,"options":["SDE1-02","SDE1-03","SDE1-04","SDE1-05","SDE2-01","SDE2-02","SDE2-03","SDE3-01","SDE3-02","SDE3-03","SDE3-04"],"title":"Building Option:","value":"SDE1-02"},"id":"21ba4064-36f4-423a-8ac5-02c6fd1e7917","type":"Select"}],"root_ids":["72eccb08-67db-43d2-86e9-2a426e88965e"]},"title":"Bokeh Application","version":"0.12.1"}};
#             var render_items = [{"docid":"6fad71c7-3902-4085-a63c-01a627c7db34","elementid":"c3500bd0-6b53-4b9a-bc72-ba46619e77d1","modelid":"72eccb08-67db-43d2-86e9-2a426e88965e","notebook_comms_target":"1bdf2028-660b-4077-b17d-3d804883213e"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# None

# %%
import numpy as np

from bokeh.plotting import figure, show, output_file

N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

TOOLS="crosshair,pan,wheel_zoom,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select"

p = figure(tools=TOOLS)

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)

output_file("color_scatter.html", title="color_scatter.py example")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="35daae1d-6519-429b-aa5a-f21461543360"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("35daae1d-6519-429b-aa5a-f21461543360");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '35daae1d-6519-429b-aa5a-f21461543360' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a8b17ec9-990e-4f83-9636-9305d51f7a2d":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"d4c6d57c-16d2-4226-a44c-698fd8ed029b","type":"BoxAnnotation"},"plot":{"id":"18bbe65c-91b8-43a6-a87b-61885a992520","subtype":"Figure","type":"Plot"},"renderers":[{"id":"247cdd47-125a-408e-98e5-879c707314cd","type":"GlyphRenderer"}]},"id":"c58d7561-46c2-48ff-8565-2f4d6911f60c","type":"BoxSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d4c6d57c-16d2-4226-a44c-698fd8ed029b","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3929b0f7-3c31-4b42-8e06-9dcd9b684c6c","type":"Circle"},{"attributes":{},"id":"c0b19439-052e-45e9-b186-0786562ed4c0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"18bbe65c-91b8-43a6-a87b-61885a992520","subtype":"Figure","type":"Plot"}},"id":"0f1868b8-491c-4547-b2bc-f050c0606515","type":"UndoTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"55e761f4-1ccc-4744-8381-026fed0f44cd","type":"PolyAnnotation"},{"attributes":{},"id":"2ce0bdb1-723e-4485-a366-a3b24617e3ae","type":"ToolEvents"},{"attributes":{"data_source":{"id":"1ccecd91-ce5c-453a-888b-f5edc6305239","type":"ColumnDataSource"},"glyph":{"id":"8965ceb7-52a1-49a7-a501-df39cae9f012","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"3929b0f7-3c31-4b42-8e06-9dcd9b684c6c","type":"Circle"},"selection_glyph":null},"id":"247cdd47-125a-408e-98e5-879c707314cd","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7b5d4ca5-8926-4b65-bbda-d5406339c267","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"c0b19439-052e-45e9-b186-0786562ed4c0","type":"BasicTickFormatter"},"plot":{"id":"18bbe65c-91b8-43a6-a87b-61885a992520","subtype":"Figure","type":"Plot"},"ticker":{"id":"8d51d15d-4593-4431-bd09-1fa4ba5a21d0","type":"BasicTicker"}},"id":"edeb7c9c-4443-427c-b0fd-c5cb41c04141","type":"LinearAxis"},{"attributes":{},"id":"8d51d15d-4593-4431-bd09-1fa4ba5a21d0","type":"BasicTicker"},{"attributes":{"plot":{"id":"18bbe65c-91b8-43a6-a87b-61885a992520","subtype":"Figure","type":"Plot"}},"id":"e53ef68c-4197-47b6-a2bb-297c8640db62","type":"CrosshairTool"},{"attributes":{"below":[{"id":"08c5d2e5-3954-4563-822a-9f5e4ce98532","type":"LinearAxis"}],"left":[{"id":"edeb7c9c-4443-427c-b0fd-c5cb41c04141","type":"LinearAxis"}],"renderers":[{"id":"08c5d2e5-3954-4563-822a-9f5e4ce98532","type":"LinearAxis"},{"id":"ee92b72a-0f63-4c10-8a74-4e62294f5b1c","type":"Grid"},{"id":"edeb7c9c-4443-427c-b0fd-c5cb41c04141","type":"LinearAxis"},{"id":"c859dc20-b1e6-4f84-a352-f0fd72fe04ad","type":"Grid"},{"id":"7b5d4ca5-8926-4b65-bbda-d5406339c267","type":"BoxAnnotation"},{"id":"d4c6d57c-16d2-4226-a44c-698fd8ed029b","type":"BoxAnnotation"},{"id":"55e761f4-1ccc-4744-8381-026fed0f44cd","type":"PolyAnnotation"},{"id":"2b7225f0-ba77-498e-981d-40a6a201754c","type":"PolyAnnotation"},{"id":"247cdd47-125a-408e-98e5-879c707314cd","type":"GlyphRenderer"}],"title":{"id":"94de9d26-b4b5-4cc6-adbd-c6d48a30cb7c","type":"Title"},"tool_events":{"id":"2ce0bdb1-723e-4485-a366-a3b24617e3ae"," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[51]</strong>&gt;</code></p>
